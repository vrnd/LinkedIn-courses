# %% [markdown]
# ![title](Header__0009_1.png "Header")
# ___
# # Chapter 1 - Data Munging Basics
# ## Segment 5 - Grouping and data aggregation

# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

# %% [markdown]
# ### Grouping data by column index

# %%
address = 'mtcars.csv'
cars = pd.read_csv(address)

cars.columns = ['car_names','mpg','cyl','disp', 'hp', 'drat', 'wt', 'qsec', 'vs', 'am', 'gear', 'carb']
#cars.shape
cars.head().T
# Out:
#                    0              1           2               3  \
# car_names  Mazda RX4  Mazda RX4 Wag  Datsun 710  Hornet 4 Drive
# mpg               21             21        22.8            21.4
# cyl                6              6           4               6
# disp             160            160         108             258
# hp               110            110          93             110
# drat             3.9            3.9        3.85            3.08
# wt              2.62          2.875        2.32           3.215
# qsec           16.46          17.02       18.61           19.44
# vs                 0              0           1               1
# am                 1              1           1               0
# gear               4              4           4               3
# carb               4              4           1               1
#
#                            4
# car_names  Hornet Sportabout
# mpg                     18.7
# cyl                        8
# disp                     360
# hp                       175
# drat                    3.15
# wt                      3.44
# qsec                   17.02
# vs                         0
# am                         0
# gear                       3
# carb                       2

# %%
# object_name.groupby('Series_name')
# ♔┈♔┈♔┈( WHAT THIS DOES )┈♔┈♔┈♔
# To group a  DataFrame by its values in a particular column, call the .groupby() method off of the DataFrame, and then pass
# in the column Series you want the DataFrame to be grouped by.
cars_groups = cars.groupby(cars['cyl'])
cars_groups.mean()
# Out:
#            mpg        disp          hp      drat        wt       qsec  \
# cyl
# 4    26.663636  105.136364   82.636364  4.070909  2.285727  19.137273
# 6    19.742857  183.314286  122.285714  3.585714  3.117143  17.977143
# 8    15.100000  353.100000  209.214286  3.229286  3.999214  16.772143
#
#            vs        am      gear      carb
# cyl
# 4    0.909091  0.727273  4.090909  1.545455
# 6    0.571429  0.428571  3.857143  3.428571
# 8    0.000000  0.142857  3.285714  3.500000

# %%
cars_group_gear = cars.groupby(cars['gear'])
cars_group_gear.mean()
# Out:
#             mpg       cyl        disp          hp      drat        wt    qsec  \
# gear
# 3     16.106667  7.466667  326.300000  176.133333  3.132667  3.892600  17.692
# 4     24.533333  4.666667  123.016667   89.500000  4.043333  2.616667  18.965
# 5     21.380000  6.000000  202.480000  195.600000  3.916000  2.632600  15.640
#
#             vs        am      carb
# gear
# 3     0.200000  0.000000  2.666667
# 4     0.833333  0.666667  2.333333
# 5     0.200000  1.000000  4.400000
