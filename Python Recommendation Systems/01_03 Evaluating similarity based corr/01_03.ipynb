# %% [markdown]
# ![title](Chapter-1.png "Header")
# ___
# # Chapter 1 - Simple Approaches to Recommender Systems
# ## Segment 3 - Making Recommendations Based on Correlation

# %%
import numpy as np
import pandas as pd
import chardet

# %%
with open("geoplaces2.csv", "rb") as rawdata:
    result = chardet.detect(rawdata.read(100000))

print(result)
# Out:
# {'encoding': 'ISO-8859-1', 'confidence': 0.7292665071770335, 'language': ''}

# %% [markdown]
# These datasets are hosted on: https://archive.ics.uci.edu/ml/datasets/Restaurant+%26+consumer+data
#
# They were originally published by: Blanca Vargas-Govea, Juan Gabriel GonzÃ¡lez-Serna, Rafael Ponce-MedellÃ­n. Effects of relevant contextual features in the performance of a restaurant recommender system. In RecSysâ€™11: Workshop on Context Aware Recommender Systems (CARS-2011), Chicago, IL, USA, October 23, 2011.

# %%
frame =  pd.read_csv('rating_final.csv')
cuisine = pd.read_csv('chefmozcuisine.csv')
geodata = pd.read_csv('geoplaces2.csv', encoding = 'ISO-8859-1')

# %%
#frame.head()
geodata.shape
# Out:
# (130, 21)

# %%
geodata.head().T
# Out:
#                                                                 0  \
# placeID                                                    134999
# latitude                                                  18.9154
# longitude                                                -99.1849
# the_geom_meter  0101000020957F000088568DE356715AC138C0A525FC46...
# name                                              Kiku Cuernavaca
# address                                                Revolucion
# city                                                   Cuernavaca
# state                                                     Morelos
# country                                                    Mexico
# fax                                                             ?
# zip                                                             ?
# alcohol                                         No_Alcohol_Served
# smoking_area                                                 none
# dress_code                                               informal
# accessibility                                    no_accessibility
# price                                                      medium
# url                                         kikucuernavaca.com.mx
# Rambience                                                familiar
# franchise                                                       f
# area                                                       closed
# other_services                                               none
#
#                                                                 1  \
# placeID                                                    132825
# latitude                                                  22.1474
# longitude                                                -100.983
# the_geom_meter  0101000020957F00001AD016568C4858C1243261274BA5...
# name                                              puesto de tacos
# address                    esquina santos degollado y leon guzman
# city                                                       s.l.p.
# state                                                      s.l.p.
# country                                                    mexico
# fax                                                             ?
# zip                                                         78280
# alcohol                                         No_Alcohol_Served
# smoking_area                                                 none
# dress_code                                               informal
# accessibility                                          completely
# price                                                         low
# url                                                             ?
# Rambience                                                familiar
# franchise                                                       f
# area                                                         open
# other_services                                               none
#
#                                                                 2  \
# placeID                                                    135106
# latitude                                                  22.1497
# longitude                                                -100.976
# the_geom_meter  0101000020957F0000649D6F21634858C119AE9BF528A3...
# name                                   El Rincón de San Francisco
# address                                           Universidad 169
# city                                              San Luis Potosi
# state                                             San Luis Potosi
# country                                                    Mexico
# fax                                                             ?
# zip                                                         78000
# alcohol                                                 Wine-Beer
# smoking_area                                          only at bar
# dress_code                                               informal
# accessibility                                           partially
# price                                                      medium
# url                                                             ?
# Rambience                                                familiar
# franchise                                                       f
# area                                                         open
# other_services                                               none
#
#                                                                 3  \
# placeID                                                    132667
# latitude                                                  23.7527
# longitude                                                -99.1634
# the_geom_meter  0101000020957F00005D67BCDDED8157C1222A2DC8D84D...
# name                               little pizza Emilio Portes Gil
# address                                   calle emilio portes gil
# city                                                    victoria
# state                                                  tamaulipas
# country                                                         ?
# fax                                                             ?
# zip                                                             ?
# alcohol                                         No_Alcohol_Served
# smoking_area                                                 none
# dress_code                                               informal
# accessibility                                          completely
# price                                                         low
# url                                                             ?
# Rambience                                                familiar
# franchise                                                       t
# area                                                       closed
# other_services                                               none
#
#                                                                 4
# placeID                                                    132613
# latitude                                                  23.7529
# longitude                                                -99.1651
# the_geom_meter  0101000020957F00008EBA2D06DC8157C194E03B7B504E...
# name                                                carnitas_mata
# address                                    lic. Emilio portes gil
# city                                                     victoria
# state                                                  Tamaulipas
# country                                                    Mexico
# fax                                                             ?
# zip                                                             ?
# alcohol                                         No_Alcohol_Served
# smoking_area                                            permitted
# dress_code                                               informal
# accessibility                                          completely
# price                                                      medium
# url                                                             ?
# Rambience                                                familiar
# franchise                                                       t
# area                                                       closed
# other_services                                               none

# %%
places =  geodata[['placeID', 'name']]
places.head()
# Out:
#    placeID                            name
# 0   134999                 Kiku Cuernavaca
# 1   132825                 puesto de tacos
# 2   135106      El Rincón de San Francisco
# 3   132667  little pizza Emilio Portes Gil
# 4   132613                   carnitas_mata

# %%
#cuisine.head()

# %% [markdown]
# ## Grouping and Ranking Data

# %%
rating = pd.DataFrame(frame.groupby('placeID')['rating'].mean())
#rating.head()
rating.sort_values('rating', ascending = False).head()
# Out:
#            rating
# placeID
# 132955   2.000000
# 135034   2.000000
# 134986   2.000000
# 132922   1.833333
# 132755   1.800000

# %%
rating['rating_count'] = pd.DataFrame(frame.groupby('placeID')['rating'].count())
rating.head()
# Out:
#          rating  rating_count
# placeID
# 132560     0.50             4
# 132561     0.75             4
# 132564     1.25             4
# 132572     1.00            15
# 132583     1.00             4

# %%
rating.describe()
# Out:
#            rating  rating_count
# count  130.000000    130.000000
# mean     1.179622      8.930769
# std      0.349354      6.124279
# min      0.250000      3.000000
# 25%      1.000000      5.000000
# 50%      1.181818      7.000000
# 75%      1.400000     11.000000
# max      2.000000     36.000000

# %%
rating.sort_values('rating_count', ascending=False).head()
# Out:
#            rating  rating_count
# placeID
# 135085   1.333333            36
# 132825   1.281250            32
# 135032   1.178571            28
# 135052   1.280000            25
# 132834   1.000000            25

# %%
places[places['placeID']==135085]
# Out:
#      placeID                    name
# 121   135085  Tortas Locas Hipocampo

# %%
cuisine[cuisine['placeID']==135085]
# Out:
#     placeID   Rcuisine
# 44   135085  Fast_Food

# %% [markdown]
# ## Preparing Data For Analysis

# %%
places_crosstab = pd.pivot_table(data=frame, values='rating', index='userID', columns='placeID')
places_crosstab.head(10).T
# Out:
# userID   U1001  U1002  U1003  U1004  U1005  U1006  U1007  U1008  U1009  U1010
# placeID
# 132560     NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 132561     NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 132564     NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 132572     NaN    NaN    NaN    NaN    NaN    1.0    1.0    NaN    NaN    NaN
# 132583     NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 132584     NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 132594     NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 132608     NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 132609     NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 132613     NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 132626     NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 132630     NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 132654     NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 132660     NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 132663     NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 132665     NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 132667     NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 132668     NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 132706     NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 132715     NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 132717     NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 132723     NaN    NaN    2.0    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 132732     NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 132733     NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 132740     NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 132754     NaN    NaN    2.0    NaN    NaN    NaN    NaN    NaN    1.0    NaN
# 132755     NaN    NaN    2.0    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 132766     NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 132767     NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 132768     NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# ...        ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 135054     NaN    NaN    NaN    NaN    NaN    NaN    NaN    1.0    NaN    NaN
# 135055     NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 135057     NaN    NaN    NaN    NaN    1.0    NaN    1.0    NaN    NaN    NaN
# 135058     NaN    NaN    NaN    NaN    NaN    NaN    1.0    NaN    1.0    1.0
# 135059     NaN    1.0    2.0    NaN    NaN    NaN    NaN    NaN    2.0    NaN
# 135060     NaN    NaN    NaN    1.0    NaN    NaN    NaN    NaN    1.0    NaN
# 135062     NaN    1.0    NaN    2.0    NaN    NaN    NaN    NaN    NaN    NaN
# 135063     NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    0.0    NaN
# 135064     NaN    NaN    0.0    NaN    NaN    NaN    NaN    NaN    NaN    0.0
# 135065     NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    1.0
# 135066     NaN    NaN    NaN    NaN    2.0    NaN    NaN    NaN    NaN    NaN
# 135069     NaN    NaN    NaN    NaN    NaN    NaN    NaN    1.0    NaN    NaN
# 135070     NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 135071     NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 135072     NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 135073     NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 135074     NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 135075     NaN    NaN    2.0    NaN    NaN    1.0    NaN    NaN    NaN    NaN
# 135076     NaN    NaN    NaN    NaN    2.0    NaN    NaN    NaN    NaN    1.0
# 135079     NaN    NaN    2.0    NaN    NaN    1.0    NaN    NaN    1.0    0.0
# 135080     NaN    NaN    2.0    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 135081     NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 135082     NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 135085     0.0    1.0    NaN    NaN    NaN    NaN    1.0    NaN    NaN    NaN
# 135086     NaN    NaN    NaN    NaN    NaN    NaN    0.0    NaN    NaN    NaN
# 135088     NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 135104     NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 135106     NaN    1.0    NaN    2.0    NaN    NaN    NaN    NaN    NaN    NaN
# 135108     NaN    NaN    NaN    NaN    NaN    NaN    1.0    1.0    NaN    NaN
# 135109     NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
# [130 rows x 10 columns]

# %%
Tortas_ratings = places_crosstab[135085]
Tortas_ratings[Tortas_ratings>=0]
# Out:
# userID
# U1001    0.0
# U1002    1.0
# U1007    1.0
# U1013    1.0
# U1016    2.0
# U1027    1.0
# U1029    1.0
# U1032    1.0
# U1033    2.0
# U1036    2.0
# U1045    2.0
# U1046    1.0
# U1049    0.0
# U1056    2.0
# U1059    2.0
# U1062    0.0
# U1077    2.0
# U1081    1.0
# U1084    2.0
# U1086    2.0
# U1089    1.0
# U1090    2.0
# U1092    0.0
# U1098    1.0
# U1104    2.0
# U1106    2.0
# U1108    1.0
# U1109    2.0
# U1113    1.0
# U1116    2.0
# U1120    0.0
# U1122    2.0
# U1132    2.0
# U1134    2.0
# U1135    0.0
# U1137    2.0
# Name: 135085, dtype: float64

# %% [markdown]
# ## Evaluating Similarity Based on Correlation

# %%
similar_to_Tortas = places_crosstab.corrwith(Tortas_ratings)

corr_Tortas = pd.DataFrame(similar_to_Tortas, columns=['PearsonR'])
corr_Tortas.dropna(inplace=True)
corr_Tortas.head()
# Out:
# /anaconda3/lib/python3.6/site-packages/numpy/lib/function_base.py:3175: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar)
# /anaconda3/lib/python3.6/site-packages/numpy/lib/function_base.py:3109: RuntimeWarning: divide by zero encountered in double_scalars
#   c *= 1. / np.float64(fact)
#          PearsonR
# placeID
# 132572  -0.428571
# 132723   0.301511
# 132754   0.930261
# 132825   0.700745
# 132834   0.814823

# %%
Tortas_corr_summary = corr_Tortas.join(rating['rating_count'])
Tortas_corr_summary.head()
# Out:
#          PearsonR  rating_count
# placeID
# 132572  -0.428571            15
# 132723   0.301511            12
# 132754   0.930261            13
# 132825   0.700745            32
# 132834   0.814823            25

# %%
Tortas_corr_summary[Tortas_corr_summary['rating_count']>=10].sort_values('PearsonR', ascending=False).head(10)
# Out:
#          PearsonR  rating_count
# placeID
# 135076   1.000000            13
# 135085   1.000000            36
# 135066   1.000000            12
# 132754   0.930261            13
# 135045   0.912871            13
# 135062   0.898933            21
# 135028   0.892218            15
# 135042   0.881409            20
# 135046   0.867722            11
# 132872   0.840168            12

# %%
places_corr_Tortas = pd.DataFrame([135085, 132754, 135045, 135062, 135028, 135042, 135046], index = np.arange(7), columns=['placeID'])
summary = pd.merge(places_corr_Tortas, cuisine,on='placeID')
summary
# Out:
#    placeID   Rcuisine
# 0   135085  Fast_Food
# 1   132754    Mexican
# 2   135028    Mexican
# 3   135042    Chinese
# 4   135046  Fast_Food

# %%
places[places['placeID']==135046]
# Out:
#     placeID                     name
# 42   135046  Restaurante El Reyecito

# %%
cuisine.Rcuisine.describe()
# Out:
# count         916
# unique         59
# top       Mexican
# freq          239
# Name: Rcuisine, dtype: object
